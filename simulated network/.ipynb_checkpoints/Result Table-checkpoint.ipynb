# %%
import networkx as nx
import pandas as pd
import pickle
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.spatial.distance as spsd
import scipy.linalg as spla
import sys
import random
import math
import itertools
import operator

# %%
with open("/Users/app/Desktop/Geo/loss.pkl",'rb') as f:
    loss=pickle.load(f)

# %%
plt.plot(loss)
plt.savefig('/Users/app/Desktop/RemoteSensingPresentation/Figure/loss_curve.png')

# %%
def style_specific_cell(x):
    global color_pos 
    color = 'background-color: red'
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    for x in color_pos:
        df1.iloc[x[0],x[1]] = color
    return df1

# %%
with open("/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/Variable/name_list.pkl",'rb') as f:
    Name_List=pickle.load(f)

# %%
path='/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/result_csv'
result=list(Path(path).glob("*"+'.csv'))
#result=list(Path('/Users/app/Desktop/MaxD/D_d/beta_1000').glob("*"+'.pkl'))
#
result=sorted(result)
len(result)
# Out:
# 5

# %%
result
# Out:
# [PosixPath('/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/result_csv/BA.csv'),
#  PosixPath('/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/result_csv/ER.csv'),
#  PosixPath('/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/result_csv/Graphon.csv'),
#  PosixPath('/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/result_csv/SBM.csv'),
#  PosixPath('/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/result_csv/WS.csv')]

# %%
R=[pd.read_csv(result[1]),pd.read_csv(result[3]),pd.read_csv(result[4]),pd.read_csv(result[0]),pd.read_csv(result[2])]
#ER  SBM WS BA Graphon
frame=pd.DataFrame(R[0].iloc[:,0])
frame=frame.rename(columns={R[0].columns[0]: "Method"})
frame.head()
# Out:
#        Method
# 0          RN
# 1          DN
# 2          PN
# 3          RE
# 4  Induced_RE

# %%
j=11
df1=pd.concat([x.iloc[:,j] for x in R], axis=1)

df=pd.concat([frame,df1], axis=1)
print(R[0].columns[j])
df.columns=['Method','ER_L2','SBM_L2','WS_L2','BA_L2','Graphon_L2']
df.head()
# Out:
# LCC L2 Distribution
#        Method      ER_L2     SBM_L2       WS_L2     BA_L2  Graphon_L2
# 0          RN   9.036140   3.948877  271.736008  2.067930    1.913677
# 1          DN   8.761830   3.539670  268.248666  2.931851    1.902876
# 2          PN   8.807236   3.741749  269.597519  2.313466    1.904198
# 3          RE  18.968129  59.912063  313.731702  2.234460   84.227606
# 4  Induced_RE   7.625129   2.769813  196.226607  2.430725    1.937368

# %%
#gcc 8

j=4
df1=pd.concat([x.iloc[:,j] for x in R], axis=1)
df2=pd.concat([x.iloc[:,j+1] for x*10**3 in R], axis=1)#*10**3
df3=pd.concat([x.iloc[:,j+2] for x*10**3 in R], axis=1)#10 **7 #10**4 for Mod Var Gcc

df=pd.concat([frame,df1,df2,df3], axis=1)
print(R[0].columns[j],'\n',R[0].columns[j+1],'\n',R[0].columns[j+2])
df.columns=['Method','ER_NMSE','SBM_NMSE','WS_NMSE','BA_NMSE','Graphon_NMSE','ER_Bias','SBM_Bias','WS_Bias','BA_Bias','Graphon_Bias','ER_Variance','SBM_Variance','WS_Variance','BA_Variance','Graphon_Variance']
df.head()
#df=pd.concat([df+[x.iloc[:,2] for x in R]], axis=1)
# Out:
# density nmse
#  density bias
#  density var
#        Method   ER_NMSE  SBM_NMSE   WS_NMSE   BA_NMSE  Graphon_NMSE   ER_Bias  \
# 0          RN  0.014450  0.018283  0.047175  0.082427      0.006554 -0.000004
# 1          DN  0.023996  0.164075  0.079521  2.584966      0.008385  0.000193
# 2          PN  0.021293  0.044216  0.067423  2.224961      0.007762  0.000156
# 3          RE  0.894767  0.932257  0.310995  0.068738      0.974443 -0.008964
# 4  Induced_RE  0.103653  0.215093  1.123759  3.179687      0.025963  0.001029
#
#    SBM_Bias       WS_Bias   BA_Bias  Graphon_Bias   ER_Variance  SBM_Variance  \
# 0  0.000013  9.690410e-07  0.000002     -0.000021  2.088367e-08  8.103673e-08
# 1  0.002529  5.006213e-05  0.003094      0.000204  2.032297e-08  1.616473e-07
# 2  0.000611  3.920528e-05  0.002661      0.000163  2.103135e-08  1.027780e-07
# 3 -0.014549  2.487238e-04 -0.000082     -0.040201  5.623182e-11  6.307334e-11
# 4  0.003319  8.982657e-04  0.003809      0.001032  1.845233e-08  2.551404e-07
#
#     WS_Variance   BA_Variance  Graphon_Variance
# 0  1.423049e-09  9.771055e-09      7.246414e-08
# 1  1.545304e-09  4.072112e-08      7.763372e-08
# 2  1.366227e-09  4.117039e-08      7.534736e-08
# 3  4.823553e-11  1.468213e-10      5.573643e-11
# 4  1.494555e-09  3.653986e-08      8.215038e-08

# %%
#delete induced method
df_drop=df[~df.Method.str.contains("Induced")]
df= df_drop.reset_index(drop=True)

# %%
color_pos=[]
for x in range(1,len(df.columns)):
    color_pos.append([df.iloc[list(df.index),x].abs().sort_values().index[0:3],x])
df_=df.style.apply(style_specific_cell, axis=None)
df_.set_precision(5)
display(df_)
# Out:
# <style  type="text/css" >
# #T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col1,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col2,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col3,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col4,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col5,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col6,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col7,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col8,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col9,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col10,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col1,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col3,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col5,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col6,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col8,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col10,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col1,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col2,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col3,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col5,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col6,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col7,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col8,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col10,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow3_col4,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow3_col9,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow7_col4,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow7_col9,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow9_col11,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow9_col12,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow9_col13,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow9_col14,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow9_col15,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow11_col13,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow13_col13,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow15_col11,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow15_col12,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow15_col14,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow15_col15,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow17_col11,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow17_col12,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow17_col14,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow17_col15,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow25_col2,#T_763c201c_3e4e_11ec_9b05_784f438b2eccrow25_col7{
#             background-color:  red;
#         }</style><table id="T_763c201c_3e4e_11ec_9b05_784f438b2ecc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Method</th>        <th class="col_heading level0 col1" >ER_NMSE</th>        <th class="col_heading level0 col2" >SBM_NMSE</th>        <th class="col_heading level0 col3" >WS_NMSE</th>        <th class="col_heading level0 col4" >BA_NMSE</th>        <th class="col_heading level0 col5" >Graphon_NMSE</th>        <th class="col_heading level0 col6" >ER_Bias</th>        <th class="col_heading level0 col7" >SBM_Bias</th>        <th class="col_heading level0 col8" >WS_Bias</th>        <th class="col_heading level0 col9" >BA_Bias</th>        <th class="col_heading level0 col10" >Graphon_Bias</th>        <th class="col_heading level0 col11" >ER_Variance</th>        <th class="col_heading level0 col12" >SBM_Variance</th>        <th class="col_heading level0 col13" >WS_Variance</th>        <th class="col_heading level0 col14" >BA_Variance</th>        <th class="col_heading level0 col15" >Graphon_Variance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_763c201c_3e4e_11ec_9b05_784f438b2ecclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col0" class="data row0 col0" >RN</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col1" class="data row0 col1" >0.01445</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col2" class="data row0 col2" >0.01828</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col3" class="data row0 col3" >0.04717</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col4" class="data row0 col4" >0.08243</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col5" class="data row0 col5" >0.00655</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col6" class="data row0 col6" >-0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col7" class="data row0 col7" >0.00001</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col8" class="data row0 col8" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col9" class="data row0 col9" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col10" class="data row0 col10" >-0.00002</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col11" class="data row0 col11" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col12" class="data row0 col12" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col13" class="data row0 col13" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col14" class="data row0 col14" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow0_col15" class="data row0 col15" >0.00000</td>
#             </tr>
#             <tr>
#                         <th id="T_763c201c_3e4e_11ec_9b05_784f438b2ecclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col0" class="data row1 col0" >DN</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col1" class="data row1 col1" >0.02400</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col2" class="data row1 col2" >0.16407</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col3" class="data row1 col3" >0.07952</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col4" class="data row1 col4" >2.58497</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col5" class="data row1 col5" >0.00838</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col6" class="data row1 col6" >0.00019</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col7" class="data row1 col7" >0.00253</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col8" class="data row1 col8" >0.00005</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col9" class="data row1 col9" >0.00309</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col10" class="data row1 col10" >0.00020</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col11" class="data row1 col11" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col12" class="data row1 col12" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col13" class="data row1 col13" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col14" class="data row1 col14" >0.00000</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow1_col15" class="data row1 col15" >0.00000</td>
#             </tr>
#             <tr>
#                         <th id="T_763c201c_3e4e_11ec_9b05_784f438b2ecclevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col0" class="data row2 col0" >PN</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col1" class="data row2 col1" >0.02129</td>
#                         <td id="T_763c201c_3e4e_11ec_9b05_784f438b2eccrow2_col2" class="data row2 col2" >0.04422</td
