# %%
import networkx as nx
import pandas as pd
import pickle
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.spatial.distance as spsd
import scipy.linalg as spla
import sys
import random
import math
import itertools
import operator

# %%
with open("/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/Variable/name_list.pkl",'rb') as f:
    Name_List=pickle.load(f)

path='/Users/app/Desktop/Net/NetSampling/real_data_pkl'
result=list(Path(path).glob("*"+'.pkl'))
#result=list(Path('/Users/app/Desktop/MaxD/D_d/beta_1000').glob("*"+'.pkl'))
#
len(result)
# Out:
# 200

# %%
node={}
for a in ['bitcoin','lastfm','p2p','coauthor','email']:
    node[str(a)]={}
    for b in ['degree','community','clust','largest']:
        node[str(a)][str(b)]={}
        
for a in ['bitcoin','lastfm','p2p','coauthor','email']:
    for b in ['degree','community','clust','largest']:
        #for c in range(1,11,1):  
                node[str(a)][str(b)]=\
                [str(x)for x in result if f"{a}_{b}" in str(x)]

# %%
Graphon_df=pd.DataFrame()
ER_df=pd.DataFrame()
SBM_df=pd.DataFrame()
BA_df=pd.DataFrame()
WS_df=pd.DataFrame()

# %%
DF={}
#for model in ['ER','BA','WS','SBM','Graphon']:
for model in ['bitcoin','lastfm','p2p','coauthor','email']:
    #Average Degree
    NMSE=[];Bias=[];Var=[];
    Den_NMSE=[];Den_Bias=[];Den_Var=[];
    Distribution=[]
    for i in range(24):
        nmse=[];bias=[];var=[];
        den_nmse=[];den_bias=[];den_var=[];
        distribution=[]
        for path in node[model]['degree']:
            with open(path,'rb') as f:
                try:r=pickle.load(f);
                except:continue
                nmse.append(r[0][i][0][0]);
                bias.append(r[0][i][0][1])
                var.append(r[0][i][0][2])
                distribution.append(r[0][i][1])
                den_nmse.append(r[0][i][2][0])
                den_bias.append(r[0][i][2][1])
                den_var.append(r[0][i][2][2]) 
            #d = {'average degree nmse': np.mean(nmse), 'average degreebias': np.mean(bias),'average degree var': np.mean(var),}
            #d['density nmse']=np.mean(den_nmse)
            #d['density bias']=np.mean(den_bias)
            #d['density var']=np.mean(den_var)
            #d['degree distribution L2']=np.mean(distribution)
            #df=pd.DataFrame(data=d)
        NMSE.append(np.mean(nmse));Bias.append(np.mean(bias));Var.append(np.mean(var))
        Den_NMSE.append(np.mean(den_nmse));Den_Bias.append(np.mean(den_bias));Den_Var.append(np.mean(den_var))
        Distribution.append(np.mean(distribution))
    df=pd.DataFrame({'average degree nmse':NMSE,'average degree bias':Bias,'average degree var':Var\
                        ,'density nmse':Den_NMSE,'density bias':Den_Bias,'density var':Den_Var,'degree distribution L2':Distribution})
        #eval(f"{model}_df")=pd.DataFrame(d)
    DF[str(model)]=df
        #exec(f'{model}_df = {df}')

            
            
    #print(len(nmse))
            
    #NMSE.append(np.mean(nmse));Bias.append(np.mean(bias));Var.append(np.mean(var));
    #Den_NMSE.append(np.mean(nmse));Den_Bias.append(np.mean(bias));Den_Var.append(np.mean(var));
    #Distribution.append(np.mean(distribution))

# %%
Name_List.remove("FFS_Prob")
Name_List.remove("Induced_FFS_Prob")

# %%
 
DF['bitcoin'].index=Name_List
DF['bitcoin']
# Out:
#                   average degree nmse  average degree bias  \
# RN                           0.134513             0.018267
# DN                           3.468710            25.888541
# PN                           3.029284            22.599578
# RE                           3.473783            25.926861
# Induced_RE                   3.473783            25.926861
# RNE                          2.294210            17.102695
# Induced_RNE                  2.294210            17.102695
# HYB                          2.547342            18.995274
# Induced_HYB                  2.547342            18.995274
# SBS                          3.503413            26.128259
# Induced_SBS                  3.503413            26.128259
# FFS_Geom                     3.534873            26.369876
# Induced_FFS_Geom             3.534873            26.369876
# BFS                          2.933434            21.134910
# Induced_BFS                  2.933434            21.134910
# DFS                          3.063354            22.176866
# Induced_DFS                  3.063354            22.176866
# RW                           3.411105            25.453947
# Induced_RW                   3.411105            25.453947
# MHRW                         2.122256            15.740631
# Induced_MHRW                 2.122256            15.740631
# FS                           3.372891            25.168863
# Induced_FS                   3.372891            25.168863
# SP                           2.641005            19.707990
#
#                   average degree var  density nmse  density bias  \
# RN                          1.002891      0.278020      0.000015
# DN                          0.653954     16.839408      0.033197
# PN                          0.920475     12.916490      0.025436
# RE                          0.632129      0.866050      0.001706
# Induced_RE                  0.632129     17.411820      0.034328
# RNE                         0.971847      0.591572      0.001166
# Induced_RNE                 0.971847      8.302345      0.016329
# HYB                         0.987104      0.624292      0.001231
# Induced_HYB                 0.987104      9.942906      0.019562
# SBS                         1.674763      1.672766      0.003303
# Induced_SBS                 1.674763     19.255844      0.037866
# FFS_Geom                    1.336768      1.672766      0.003303
# Induced_FFS_Geom            1.336768     19.411260      0.038197
# BFS                        32.944749      1.672766      0.003303
# Induced_BFS                32.944749     17.061098      0.032246
# DFS                        31.183530      1.672766      0.003303
# Induced_DFS                31.183530     17.495830      0.033251
# RW                          0.869957      2.623388      0.005174
# Induced_RW                  0.869957     17.905818      0.035284
# MHRW                        3.362837      2.051443      0.004048
# Induced_MHRW                3.362837     10.179498      0.019921
# FS                          0.846913      2.522938      0.004976
# Induced_FS                  0.846913     17.524718      0.034529
# SP                          0.498166     10.204162      0.020113
#
#                    density var  degree distribution L2
# RN                2.995499e-07                0.012603
# DN                3.359642e-06                5.983043
# PN                3.355609e-06                4.187231
# RE                1.232949e-08                6.015658
# Induced_RE        3.386417e-06                6.015658
# RNE               3.700918e-09                2.003622
# Induced_RNE       2.063960e-06                2.003622
# HYB               4.402112e-09                2.627699
# Induced_HYB       2.700324e-06                2.627699
# SBS               3.009266e-36                6.214257
# Induced_SBS       1.152164e-05                6.214257
# FFS_Geom          3.009266e-36                6.323453
# Induced_FFS_Geom  9.838760e-06                6.323453
# BFS               3.009266e-36                4.273592
# Induced_BFS       9.446060e-05                4.273592
# DFS               3.009266e-36                4.677731
# Induced_DFS       8.703819e-05                4.677731
# RW                5.236906e-08                5.775818
# Induced_RW        4.891285e-06                5.775818
# MHRW              1.751434e-08                3.018364
# Induced_MHRW      7.099822e-06                3.018364
# FS                4.960065e-08                5.603169
# Induced_FS        4.907973e-06                5.603169
# SP                1.349235e-06                2.634131

# %%
for model in ['bitcoin','lastfm','p2p','coauthor','email']:
    #Average Degree
    NMSE=[];Bias=[];Var=[];
    Den_NMSE=[];Den_Bias=[];Den_Var=[];
    Distribution=[]
    for i in range(24):
        nmse=[];bias=[];var=[];
        den_nmse=[];den_bias=[];den_var=[];
        distribution=[]
        for path in node[model]['clust']:
            with open(path,'rb') as f:
                try:r=pickle.load(f);
                except:continue
                nmse.append(r[0][i][0][0]);
                bias.append(r[0][i][0][1])
                var.append(r[0][i][0][2])
                distribution.append(r[0][i][2])
                den_nmse.append(r[0][i][1][0])
                den_bias.append(r[0][i][1][1])
                den_var.append(r[0][i][1][2]) 
                
        NMSE.append(np.mean(nmse));Bias.append(np.mean(bias));Var.append(np.mean(var))
        Den_NMSE.append(np.mean(den_nmse));Den_Bias.append(np.mean(den_bias));Den_Var.append(np.mean(den_var))
        Distribution.append(np.mean(distribution))
    DF[str(model)]['gcc nmse']=NMSE
    DF[str(model)]['gcc bias']=Bias
    DF[str(model)]['gcc var']=Var
    DF[str(model)]['LCC L2 Distribution']=Distribution
    DF[str(model)]['average lcc nmse']=Den_NMSE
    DF[str(model)]['average lcc bias']=Den_Bias
    DF[str(model)]['average lcc var']=Den_Var

# %%
for model in ['bitcoin','lastfm','p2p','coauthor','email']:
    #Average Degree
    NMSE=[];Bias=[];Var=[];
    Den_NMSE=[];Den_Bias=[];Den_Var=[];
    #Distribution=[]
    for i in range(24):
        nmse=[];bias=[];var=[];
        den_nmse=[];den_bias=[];den_var=[];
        #distribution=[]
        for path in node[model]['community']:
            with open(path,'rb') as f:
                try:r=pickle.load(f);
                except:continue
                nmse.append(r[0][i][0][0]);
                bias.append(r[0][i][0][1])
                var.append(r[0][i][0][2])
                #distribution.append(r[0][i][2])
                den_nmse.append(r[0][i][1][0])
                den_bias.append(r[0][i][1][1])
                den_var.append(r[0][i][1][2]) 
                
        NMSE.append(np.mean(nmse));Bias.append(np.mean(bias));Var.append(np.mean(var))
        Den_NMSE.append(np.mean(den_nmse));Den_Bias.append(np.mean(den_bias));Den_Var.append(np.mean(den_var))
        #Distribution.append(np.mean(distribution))
    DF[str(model)]['mod nmse']=NMSE
    DF[str(model)]['mod bias']=Bias
    DF[str(model)]['mod var']=Var
    #DF[str(model)]['LCC L2 Distribution']=Distribution
    DF[str(model)]['mod num nmse']=Den_NMSE
    DF[str(model)]['mod num bias']=Den_Bias
    DF[str(model)]['mod num var']=Den_Var

# %%
for model in ['bitcoin','lastfm','p2p','coauthor','email']:
    #Average Degree
    NMSE=[];Bias=[];Var=[];
    Den_NMSE=[];Den_Bias=[];Den_Var=[];
    #Distribution=[]
    for i in range(24):
        nmse=[];bias=[];var=[];
        den_nmse=[];den_bias=[];den_var=[];
        #distribution=[]
        for path in node[model]['largest']:
            with open(path,'rb') as f:
                try:r=pickle.load(f);
                except:continue
                nmse.append(r[0][i][0][0]);
                bias.append(r[0][i][0][1])
                var.append(r[0][i][0][2])
                #distribution.append(r[0][i][2])
                den_nmse.append(r[0][i][1][0])
                den_bias.append(r[0][i][1][1])
                den_var.append(r[0][i][1][2]) 
                
        NMSE.append(np.mean(nmse));Bias.append(np.mean(bias));Var.append(np.mean(var))
        Den_NMSE.append(np.mean(den_nmse));Den_Bias.append(np.mean(den_bias));Den_Var.append(np.mean(den_var))
        #Distribution.append(np.mean(distribution))
    DF[str(model)]['largest eigenvalue nmse']=NMSE
    DF[str(model)]['largest eigenvalue bias']=Bias
    DF[str(model)]['largest eigenvalue var']=Var
    #DF[str(model)]['LCC L2 Distribution']=Distribution
    DF[str(model)]['2nd largest eigenvalue nmse']=Den_NMSE
    DF[str(model)]['2nd largest eigenvalue bias']=Den_Bias
    DF[str(model)]['2nd largest eigenvalue var']=Den_Var

# %%
for model in ['bitcoin','lastfm','p2p','coauthor','email']:
    DF[str(model)].index=Name_List
    DF[str(model)].to_csv(f"/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/result_csv/{model}.csv")
    DF[str(model)].to_excel(f"/Users/app/Desktop/科研资料/With Prof/Prof Qin/Networ Sampling/result_csv/{model}.xlsx")
